# %% [markdown]
# # Họ tên: Vương Thanh Linh
# # MSSV: 21521082

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
import seaborn as sns
import plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
with open('/content/drive/MyDrive/Data Mining/Lab5/titanic.csv') as f:
    df = pd.read_csv(f, dtype={'age': np.float64, 'sibsp': np.int64, 'parch': np.int64})

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent_1 = df.isnull().sum() / df.isnull().count() * 100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(5)
# Out:
#            Total     %
# body        1188  90.8
# cabin       1014  77.5
# boat         823  62.9
# home.dest    564  43.1
# age          263  20.1

# %%
import re
deck = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "U": 8}

for data in [df]:
    data['cabin'] = data['cabin'].fillna("U0")
    data['deck'] = data['cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    data['deck'] = data['deck'].map(deck)
    data['deck'] = data['deck'].fillna(0)
    data['deck'] = data['deck'].astype(int)
df = df.drop(['cabin'], axis=1)

# %%
df = df.drop(['ticket'], axis=1)
df = df.drop(['boat'], axis=1)
df = df.drop(['body'], axis=1)
df = df.drop(['home.dest'], axis=1)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch      fare embarked  deck
# 0  29.0000      0      0  211.3375        S     2
# 1   0.9167      1      2  151.5500        S     3
# 2   2.0000      1      2  151.5500        S     3
# 3  30.0000      1      2  151.5500        S     3
# 4  25.0000      1      2  151.5500        S     3

# %%
for data in [df]:
    mean = df['age'].mean()
    std = df['age'].std()
    is_null = data['age'].isnull().sum()
    #compute random numbers
    rand_age = np.random.randint(mean - std, mean + std, size=is_null)
    #fill NA
    age_slice = data['age'].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    data['age'] = age_slice
    data['age'] = df['age'].astype(int)
df['age'].isnull().sum()
# Out:
# 0

# %%
df = df.drop(['name'],axis =1)
df = df.drop(['sex'],axis =1)
df.head()
# Out:
#    pclass  survived  age  sibsp  parch      fare embarked  deck
# 0       1         1   29      0      0  211.3375        S     2
# 1       1         1    0      1      2  151.5500        S     3
# 2       1         0    2      1      2  151.5500        S     3
# 3       1         0   30      1      2  151.5500        S     3
# 4       1         0   25      1      2  151.5500        S     3

# %%
pd.get_dummies(df)
feature = df.drop('survived',axis=1)
label = df['survived']
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.635600     0.498854     0.385027
# std       0.837836     0.486055    13.434778     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    38.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare         deck
# count  1308.000000  1309.000000
# mean     33.295479     6.948816
# std      51.758668     2.065364
# min       0.000000     0.000000
# 25%       7.895800     8.000000
# 50%      14.454200     8.000000
# 75%      31.275000     8.000000
# max     512.329200     8.000000

# %%
X1 = feature[['age', 'parch']].iloc[: , :].values

algo = KMeans(n_clusters = 2, init = 'random')
algo.fit(X1)
labels1 = algo.labels_
centroids1 = algo.cluster_centers_

plt.figure(1, figsize = (15, 7))
plt.clf()
plt.scatter(x = 'age', y = 'parch', data = df, c = labels1, s = 200)
plt.scatter(x = centroids1[: , 0], y = centroids1[: , 1], s =300, c = 'red', alpha = 0.5)
plt.ylabel('Parch'), plt.xlabel('Age')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
metrics.silhouette_score(X1, labels1, metric = 'euclidean')
# Out:
# 0.5642582918760262

# %%
x_train,x_test,y_train,y_test = train_test_split(feature,label,test_size=0.3,random_state=0)

# %%
x1_train = x_train[['age', 'parch']].iloc[: , :].values
algorithm = KMeans(n_clusters = 2, init = 'random')
algorithm.fit(x1_train,y_train)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
x_test = x_test[['age','parch']]

# %%
KMean_pred = algorithm.predict(x_test)

KMeans_score = metrics.accuracy_score(y_test,KMean_pred)
print("Accruracy:",KMeans_score)
print("Report:",metrics.classification_report(y_test,KMean_pred))
# Out:
# Accruracy: 0.4631043256997455
# Report:               precision    recall  f1-score   support
#
#            0       0.63      0.34      0.44       246
#            1       0.38      0.67      0.48       147
#
#     accuracy                           0.46       393
#    macro avg       0.51      0.51      0.46       393
# weighted avg       0.54      0.46      0.46       393
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(

# %%
KMeans_cm = metrics.confusion_matrix(y_test,KMean_pred)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(KMeans_cm,annot=True, fmt=".3f",linewidth=.5,square=True,cmap='Blues_r');
plt.xlabel('Actual Label');
plt.ylabel('Predicted Label');
plt.title(f'K-Means Accuracy Score: {KMeans_score}',size=15);
