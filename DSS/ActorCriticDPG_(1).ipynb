# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import gym
import numpy as np
import keras
from keras import ops
from keras import layers
import tensorflow as tf
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %%
# Environment setup
env = gym.make("CartPole-v1")
num_inputs = 4
num_actions = 1  # Deterministic actions
num_hidden = 128
gamma = 0.99
exploration_noise_std = 0.1
max_steps_per_episode = 500
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
# Actor model
actor_inputs = layers.Input(shape=(num_inputs,))
actor_hidden = layers.Dense(num_hidden, activation="relu")(actor_inputs)
actor_output = layers.Dense(num_actions, activation="tanh")(actor_hidden)
actor_model = tf.keras.Model(inputs=actor_inputs, outputs=actor_output)

# %%
# Critic model
critic_inputs = layers.Input(shape=(num_inputs + num_actions,))
critic_hidden = layers.Dense(num_hidden, activation="relu")(critic_inputs)
q_value = layers.Dense(1)(critic_hidden)
critic_model = tf.keras.Model(inputs=critic_inputs, outputs=q_value)

actor_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
critic_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
# Optimizers
actor_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
critic_optimizer = tf.keras.optimizers.Adam(learning_rate=0.002)

# Replay buffer setup
class ReplayBuffer:
    def __init__(self, buffer_capacity=100000, batch_size=64):
        self.buffer_capacity = buffer_capacity
        self.batch_size = batch_size
        self.buffer_counter = 0
        self.state_buffer = np.zeros((buffer_capacity, num_inputs))
        self.action_buffer = np.zeros((buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((buffer_capacity, 1))
        self.next_state_buffer = np.zeros((buffer_capacity, num_inputs))
        self.done_buffer = np.zeros((buffer_capacity, 1))

    def store(self, state, action, reward, next_state, done):
        index = self.buffer_counter % self.buffer_capacity
        self.state_buffer[index] = state
        self.action_buffer[index] = action
        self.reward_buffer[index] = reward
        self.next_state_buffer[index] = next_state
        self.done_buffer[index] = done
        self.buffer_counter += 1

    def sample(self):
        max_buffer = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(max_buffer, self.batch_size)
        return (
            self.state_buffer[batch_indices],
            self.action_buffer[batch_indices],
            self.reward_buffer[batch_indices],
            self.next_state_buffer[batch_indices],
            self.done_buffer[batch_indices],
        )

# Initialize replay buffer
buffer = ReplayBuffer()

# %%
# Training loop
for episode in range(1000):
    state = env.reset()
    episode_reward = 0

    for step in range(max_steps_per_episode):
        state_tensor = tf.convert_to_tensor(state, dtype=tf.float32)
        state_tensor = tf.expand_dims(state_tensor, axis=0)

        # Actor chooses action deterministically
        action = actor_model(state_tensor).numpy()[0]
        action += np.random.normal(0, exploration_noise_std)  # Add noise for exploration
        action = np.clip(action, -1, 1)  # Ensure action is within valid range

        # Execute action in environment
        next_state, reward, done, _ = env.step(int(action > 0))  # Convert continuous action to discrete
        episode_reward += reward

        # Store transition in replay buffer
        buffer.store(state, action, reward, next_state, done)

        # Train models if the replay buffer has enough samples
        if buffer.buffer_counter >= buffer.batch_size:
            states, actions, rewards, next_states, dones = buffer.sample()

            # Convert to tensors
            states = tf.convert_to_tensor(states, dtype=tf.float32)
            actions = tf.convert_to_tensor(actions, dtype=tf.float32)
            rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
            next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
            dones = tf.convert_to_tensor(dones, dtype=tf.float32)

            # Critic training
            with tf.GradientTape() as tape:
                # Target Q-value
                target_actions = actor_model(next_states)
                target_q_values = rewards + (1 - dones) * gamma * critic_model(
                    tf.concat([next_states, target_actions], axis=1)
                )
                # Predicted Q-value
                predicted_q_values = critic_model(tf.concat([states, actions], axis=1))
                critic_loss = tf.keras.losses.MSE(target_q_values, predicted_q_values)

            critic_grads = tape.gradient(critic_loss, critic_model.trainable_variables)
            critic_optimizer.apply_gradients(zip(critic_grads, critic_model.trainable_variables))

            # Actor training
            with tf.GradientTape() as tape:
                # Actor loss is the negative of the Q-value
                actions_pred = actor_model(states)
                actor_loss = -tf.reduce_mean(critic_model(tf.concat([states, actions_pred], axis=1)))

            actor_grads = tape.gradient(actor_loss, actor_model.trainable_variables)
            actor_optimizer.apply_gradients(zip(actor_grads, actor_model.trainable_variables))

        if done:
            break
        state = next_state

    print(f"Episode {episode + 1}: Reward: {episode_reward:.2f}")

    if episode_reward > 475:
        print("Solved!")
        break
# Out:
# <ipython-input-6-429cab3f941e>:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   next_state, reward, done, _ = env.step(int(action > 0))  # Convert continuous action to discrete
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 1: Reward: 81.00
# Episode 2: Reward: 12.00
# Episode 3: Reward: 9.00
# Episode 4: Reward: 10.00
# Episode 5: Reward: 8.00
# Episode 6: Reward: 11.00
# Episode 7: Reward: 10.00
# Episode 8: Reward: 12.00
# Episode 9: Reward: 10.00
# Episode 10: Reward: 8.00
# Episode 11: Reward: 8.00
# Episode 12: Reward: 9.00
# Episode 13: Reward: 10.00
# Episode 14: Reward: 23.00
# Episode 15: Reward: 9.00
# Episode 16: Reward: 10.00
# Episode 17: Reward: 9.00
# Episode 18: Reward: 10.00
# Episode 19: Reward: 10.00
# Episode 20: Reward: 10.00
# Episode 21: Reward: 11.00
# Episode 22: Reward: 9.00
# Episode 23: Reward: 9.00
# Episode 24: Reward: 8.00
# Episode 25: Reward: 8.00
# Episode 26: Reward: 10.00
# Episode 27: Reward: 10.00
# Episode 28: Reward: 10.00
# Episode 29: Reward: 8.00
# Episode 30: Reward: 9.00
# Episode 31: Reward: 9.00
# Episode 32: Reward: 10.00
# Episode 33: Reward: 9.00
# Episode 34: Reward: 9.00
# Episode 35: Reward: 8.00
# Episode 36: Reward: 10.00
# Episode 37: Reward: 9.00
# Episode 38: Reward: 9.00
# Episode 39: Reward: 9.00
# Episode 40: Reward: 9.00
# Episode 41: Reward: 8.00
# Episode 42: Reward: 9.00
# Episode 43: Reward: 10.00
# Episode 44: Reward: 8.00
# Episode 45: Reward: 9.00
# Episode 46: Reward: 10.00
# Episode 47: Reward: 9.00
# Episode 48: Reward: 10.00
# Episode 49: Reward: 10.00
# Episode 50: Reward: 11.00
# Episode 51: Reward: 8.00
# Episode 52: Reward: 9.00
# Episode 53: Reward: 14.00
# Episode 54: Reward: 24.00
# Episode 55: Reward: 30.00
# Episode 56: Reward: 10.00
# Episode 57: Reward: 9.00
# Episode 58: Reward: 8.00
# Episode 59: Reward: 19.00
# Episode 60: Reward: 9.00
# Episode 61: Reward: 10.00
# Episode 62: Reward: 10.00
# Episode 63: Reward: 10.00
# Episode 64: Reward: 10.00
# Episode 65: Reward: 10.00
# Episode 66: Reward: 10.00
# Episode 67: Reward: 11.00
# Episode 68: Reward: 10.00
# Episode 69: Reward: 9.00
# Episode 70: Reward: 9.00
# Episode 71: Reward: 10.00
# Episode 72: Reward: 9.00
# Episode 73: Reward: 10.00
# Episode 74: Reward: 9.00
# Episode 75: Reward: 10.00
# Episode 76: Reward: 9.00
# Episode 77: Reward: 15.00
# Episode 78: Reward: 11.00
# Episode 79: Reward: 14.00
# Episode 80: Reward: 8.00
# Episode 81: Reward: 11.00
# Episode 82: Reward: 16.00
# Episode 83: Reward: 14.00
# Episode 84: Reward: 9.00
# Episode 85: Reward: 12.00
# Episode 86: Reward: 14.00
# Episode 87: Reward: 10.00
# Episode 88: Reward: 17.00
# Episode 89: Reward: 9.00
# Episode 90: Reward: 10.00
# Episode 91: Reward: 11.00
# Episode 92: Reward: 11.00
# Episode 93: Reward: 12.00
# Episode 94: Reward: 21.00
# Episode 95: Reward: 11.00
# Episode 96: Reward: 16.00
# Episode 97: Reward: 9.00
# Episode 98: Reward: 12.00
# Episode 99: Reward: 12.00
# Episode 100: Reward: 26.00
# Episode 101: Reward: 10.00
# Episode 102: Reward: 27.00
# Episode 103: Reward: 57.00
# Episode 104: Reward: 55.00
# Episode 105: Reward: 32.00
# Episode 106: Reward: 35.00
# Episode 107: Reward: 33.00
# Episode 108: Reward: 96.00
# Episode 109: Reward: 16.00
# Episode 110: Reward: 9.00
# Episode 111: Reward: 18.00
# Episode 112: Reward: 12.00
# Episode 113: Reward: 14.00
# Episode 114: Reward: 35.00
# Episode 115: Reward: 19.00
# Episode 116: Reward: 9.00
# Episode 117: Reward: 11.00
# Episode 118: Reward: 11.00
# Episode 119: Reward: 9.00
# Episode 120: Reward: 18.00
# Episode 121: Reward: 10.00
# Episode 122: Reward: 40.00
# Episode 123: Reward: 37.00
# Episode 124: Reward: 35.00
# Episode 125: Reward: 12.00
# Episode 126: Reward: 16.00
# Episode 127: Reward: 35.00
# Episode 128: Reward: 35.00
# Episode 129: Reward: 15.00
# Episode 130: Reward: 22.00
# Episode 131: Reward: 30.00
# Episode 132: Reward: 10.00
# Episode 133: Reward: 34.00
# Episode 134: Reward: 12.00
# Episode 135: Reward: 30.00
# Episode 136: Reward: 48.00
# Episode 137: Reward: 161.00
# Episode 138: Reward: 56.00
# Episode 139: Reward: 50.00
# Episode 140: Reward: 37.00
# Episode 141: Reward: 70.00
# Episode 142: Reward: 39.00
# Episode 143: Reward: 23.00
# Episode 144: Reward: 10.00
# Episode 145: Reward: 44.00
# Episode 146: Reward: 137.00
# Episode 147: Reward: 89.00
# Episode 148: Reward: 16.00
# Episode 149: Reward: 33.00
# Episode 150: Reward: 64.00
# Episode 151: Reward: 116.00
# Episode 152: Reward: 167.00
# Episode 153: Reward: 103.00
# Episode 154: Reward: 122.00
# Episode 155: Reward: 79.00
# Episode 156: Reward: 84.00
# Episode 157: Reward: 134.00
# Episode 158: Reward: 17.00
# Episode 159: Reward: 98.00
# Episode 160: Reward: 65.00
# Episode 161: Reward: 115.00
# Episode 162: Reward: 18.00
# Episode 163: Reward: 18.00
# Episode 164: Reward: 164.00
# Episode 165: Reward: 31.00
# Episode 166: Reward: 29.00
# Episode 167: Reward: 111.00
# Episode 168: Reward: 114.00
# Episode 169: Reward: 18.00
# Episode 170: Reward: 25.00
# Episode 171: Reward: 53.00
# Episode 172: Reward: 105.00
# Episode 173: Reward: 52.00
# Episode 174: Reward: 90.00
# Episode 175: Reward: 24.00
# Episode 176: Reward: 67.00
# Episode 177: Reward: 40.00
# Episode 178: Reward: 53.00
# Episode 179: Reward: 67.00
# Episode 180: Reward: 45.00
# Episode 181: Reward: 42.00
# Episode 182: Reward: 82.00
# Episode 183: Reward: 49.00
# Episode 184: Reward: 78.00
# Episode 185: Reward: 85.00
# Episode 186: Reward: 234.00
# Episode 187: Reward: 194.00
# Episode 188: Reward: 47.00
# Episode 189: Reward: 103.00
# Episode 190: Reward: 14.00
# Episode 191: Reward: 20.00
# Episode 192: Reward: 104.00
# Episode 193: Reward: 72.00
# Episode 194: Reward: 78.00
# Episode 195: Reward: 138.00
# Episode 196: Reward: 109.00
# Episode 197: Reward: 35.00
# Episode 198: Reward: 90.00
# Episode 199: Reward: 105.00
# Episode 200: Reward: 82.00
# Episode 201: Reward: 169.00
# Episode 202: Reward: 46.00
# Episode 203: Reward: 49.00
# Episode 204: Reward: 71.00
# Episode 205: Reward: 147.00
# Episode 206: Reward: 63.00
# Episode 207: Reward: 47.00
# Episode 208: Reward: 86.00
# Episode 209: Reward: 173.00
# Episode 210: Reward: 35.00
# Episode 211: Reward: 33.00
# Episode 212: Reward: 70.00
# Episode 213: Reward: 73.00
# Episode 214: Reward: 86.00
# Episode 215: Reward: 54.00
# Episode 216: Reward: 76.00
# Episode 217: Reward: 54.00
# Episode 218: Reward: 100.00
# Episode 219: Reward: 29.00
# Episode 220: Reward: 39.00
# Episode 221: Reward: 122.00
# Episode 222: Reward: 43.00
# Episode 223: Reward: 139.00
# Episode 224: Reward: 89.00
# Episode 225: Reward: 47.00
# Episode 226: Reward: 114.00
# Episode 227: Reward: 57.00
# Episode 228: Reward: 38.00
# Episode 229: Reward: 57.00
# Episode 230: Reward: 46.00
# Episode 231: Reward: 187.00
# Episode 232: Reward: 84.00
# Episode 233: Reward: 117.00
# Episode 234: Reward: 168.00
# Episode 235: Reward: 34.00
# Episode 236: Reward: 57.00
# Episode 237: Reward: 72.00
# Episode 238: Reward: 169.00
# Episode 239: Reward: 72.00
# Episode 240: Reward: 59.00
# Episode 241: Reward: 63.00
# Episode 242: Reward: 37.00
# Episode 243: Reward: 49.00
# Episode 244: Reward: 40.00
# Episode 245: Reward: 47.00
# Episode 246: Reward: 67.00
# Episode 247: Reward: 76.00
# Episode 248: Reward: 51.00
# Episode 249: Reward: 47.00
# Episode 250: Reward: 69.00
# Episode 251: Reward: 40.00
# Episode 252: Reward: 88.00
# Episode 253: Reward: 36.00
# Episode 254: Reward: 59.00
# Episode 255: Reward: 247.00
# Episode 256: Reward: 59.00
# Episode 257: Reward: 27.00
# Episode 258: Reward: 62.00
# Episode 259: Reward: 43.00
# Episode 260: Reward: 41.00
# Episode 261: Reward: 89.00
# Episode 262: Reward: 92.00
# Episode 263: Reward: 65.00
# Episode 264: Reward: 121.00
# Episode 265: Reward: 117.00
# Episode 266: Reward: 108.00
# Episode 267: Reward: 35.00
# Episode 268: Reward: 109.00
# Episode 269: Reward: 138.00
# Episode 270: Reward: 131.00
# Episode 271: Reward: 73.00
# Episode 272: Reward: 40.00
# Episode 273: Reward: 78.00
# Episode 274: Reward: 196.00
# Episode 275: Reward: 70.00
# Episode 276: Reward: 94.00
# Episode 277: Reward: 30.00
# Episode 278: Reward: 66.00
# Episode 279: Reward: 109.00
# Episode 280: Reward: 145.00
# Episode 281: Reward: 105.00
# Episode 282: Reward: 172.00
# Episode 283: Reward: 68.00
# Episode 284: Reward: 45.00
# Episode 285: Reward: 80.00
# Episode 286: Reward: 87.00
# Episode 287: Reward: 96.00
# Episode 288: Reward: 36.00
# Episode 289: Reward: 49.00
# Episode 290: Reward: 177.00
# Episode 291: Reward: 163.00
# Episode 292: Reward: 25.00
# Episode 293: Reward: 64.00
# Episode 294: Reward: 36.00
# Episode 295: Reward: 201.00
# Episode 296: Reward: 140.00
# Episode 297: Reward: 130.00
# Episode 298: Reward: 93.00
# Episode 299: Reward: 51.00
# Episode 300: Reward: 46.00
# Episode 301: Reward: 72.00
# Episode 302: Reward: 29.00
# Episode 303: Reward: 73.00
# Episode 304: Reward: 70.00
# Episode 305: Reward: 97.00
# Episode 306: Reward: 64.00
# Episode 307: Reward: 120.00
# Episode 308: Reward: 154.00
# Episode 309: Reward: 208.00
# Episode 310: Reward: 43.00
# Episode 311: Reward: 83.00
# Episode 312: Reward: 64.00
# Episode 313: Reward: 143.00
# Episode 314: Reward: 35.00
# Episode 315: Reward: 52.00
# Episode 316: Reward: 46.00
# Episode 317: Reward: 73.00
# Episode 318: Reward: 51.00
# Episode 319: Reward: 48.00
# Episode 320: Reward: 59.00
# Episode 321: Reward: 71.00
# Episode 322: Reward: 116.00
# Episode 323: Reward: 169.00
# Episode 324: Reward: 68.00
# Episode 325: Reward: 124.00
# Episode 326: Reward: 76.00
# Episode 327: Reward: 72.00
# Episode 328: Reward: 30.00
# Episode 329: Reward: 176.00
# Episode 330: Reward: 121.00
# Episode 331: Reward: 240.00
# Episode 332: Reward: 67.00
# Episode 333: Reward: 212.00
# Episode 334: Reward: 90.00
# Episode 335: Reward: 83.00
# Episode 336: Reward: 29.00
# Episode 337: Reward: 38.00
# Episode 338: Reward: 75.00
# Episode 339: Reward: 46.00
# Episode 340: Reward: 36.00
# Episode 341: Reward: 23.00
# Episode 342: Reward: 85.00
# Episode 343: Reward: 53.00
# Episode 344: Reward: 29.00
# Episode 345: Reward: 184.00
# Episode 346: Reward: 167.00
# Episode 347: Reward: 85.00
# Episode 348: Reward: 182.00
# Episode 349: Reward: 186.00
# Episode 350: Reward: 41.00
# Episode 351: Reward: 67.00
# Episode 352: Reward: 431.00
# Episode 353: Reward: 156.00
# Episode 354: Reward: 154.00
# Episode 355: Reward: 198.00
# Episode 356: Reward: 37.00
# Episode 357: Reward: 208.00
# Episode 358: Reward: 119.00
# Episode 359: Reward: 196.00
# Episode 360: Reward: 31.00
# Episode 361: Reward: 108.00
# Episode 362: Reward: 233.00
# Episode 363: Reward: 116.00
# Episode 364: Reward: 298.00
# Episode 365: Reward: 124.00
# Episode 366: Reward: 174.00
# Episode 367: Reward: 71.00
# Episode 368: Reward: 75.00
# Episode 369: Reward: 113.00
# Episode 370: Reward: 95.00
# Episode 371: Reward: 70.00
# Episode 372: Reward: 113.00
# Episode 373: Reward: 78.00
# Episode 374: Reward: 97.00
# Episode 375: Reward: 93.00
# Episode 376: Reward: 83.00
# Episode 377: Reward: 134.00
# Episode 378: Reward: 100.00
# Episode 379: Reward: 98.00
# Episode 380: Reward: 33.00
# Episode 381: Reward: 60.00
# Episode 382: Reward: 89.00
# Episode 383: Reward: 28.00
# Episode 384: Reward: 103.00
# Episode 385: Reward: 36.00
# Episode 386: Reward: 89.00
# Episode 387: Reward: 35.00
# Episode 388: Reward: 268.00
# Episode 389: Reward: 76.00
# Episode 390: Reward: 31.00
# Episode 391: Reward: 59.00
# Episode 392: Reward: 54.00
# Episode 393: Reward: 250.00
# Episode 394: Reward: 41.00
# Episode 395: Reward: 166.00
# Episode 396: Reward: 58.00
# Episode 397: Reward: 42.00
# Episode 398: Reward: 197.00
# Episode 399: Reward: 167.00
# Episode 400: Reward: 151.00
# Episode 401: Reward: 30.00
# Episode 402: Reward: 90.00
# Episode 403: Reward: 101.00
# Episode 404: Reward: 75.00
# Episode 405: Reward: 380.00
# Episode 406: Reward: 132.00
# Episode 407: Reward: 49.00
# Episode 408: Reward: 78.00
# Episode 409: Reward: 121.00
# Episode 410: Reward: 322.00
# Episode 411: Reward: 106.00
# Episode 412: Reward: 95.00
# Episode 413: Reward: 142.00
# Episode 414: Reward: 163.00
# Episode 415: Reward: 140.00
# Episode 416: Reward: 100.00
# Episode 417: Reward: 222.00
# Episode 418: Reward: 203.00
# Episode 419: Reward: 72.00
# Episode 420: Reward: 142.00
# Episode 421: Reward: 92.00
# Episode 422: Reward: 166.00
# Episode 423: Reward: 118.00
# Episode 424: Reward: 139.00
# Episode 425: Reward: 164.00
# Episode 426: Reward: 82.00
# Episode 427: Reward: 134.00
# Episode 428: Reward: 78.00
# Episode 429: Reward: 59.00
# Episode 430: Reward: 205.00
# Episode 431: Reward: 85.00
# Episode 432: Reward: 132.00
# Episode 433: Reward: 87.00
# Episode 434: Reward: 235.00
# Episode 435: Reward: 92.00
# Episode 436: Reward: 73.00
# Episode 437: Reward: 72.00
# Episode 438: Reward: 47.00
# Episode 439: Reward: 30.00
# Episode 440: Reward: 236.00
# Episode 441: Reward: 350.00
# Episode 442: Reward: 147.00
# Episode 443: Reward: 59.00
# Episode 444: Reward: 99.00
# Episode 445: Reward: 218.00
# Episode 446: Reward: 30.00
# Episode 447: Reward: 109.00
# Episode 448: Reward: 122.00
# Episode 449: Reward: 159.00
# Episode 450: Reward: 299.00
# Episode 451: Reward: 187.00
# Episode 452: Reward: 85.00
# Episode 453: Reward: 112.00
# Episode 454: Reward: 243.00
# Episode 455: Reward: 175.00
# Episode 456: Reward: 182.00
# Episode 457: Reward: 90.00
# Episode 458: Reward: 104.00
# Episode 459: Reward: 98.00
# Episode 460: Reward: 128.00
# Episode 461: Reward: 202.00
# Episode 462: Reward: 120.00
# Episode 463: Reward: 199.00
# Episode 464: Reward: 124.00
# Episode 465: Reward: 107.00
# Episode 466: Reward: 142.00
# Episode 467: Reward: 70.00
# Episode 468: Reward: 169.00
# Episode 469: Reward: 45.00
# Episode 470: Reward: 65.00
# Episode 471: Reward: 61.00
# Episode 472: Reward: 177.00
# Episode 473: Reward: 123.00
# Episode 474: Reward: 130.00
# Episode 475: Reward: 71.00
# Episode 476: Reward: 58.00
# Episode 477: Reward: 161.00
# Episode 478: Reward: 147.00
# Episode 479: Reward: 209.00
# Episode 480: Reward: 24.00
# Episode 481: Reward: 96.00
# Episode 482: Reward: 106.00
# Episode 483: Reward: 110.00
# Episode 484: Reward: 229.00
# Episode 485: Reward: 113.00
# Episode 486: Reward: 274.00
# Episode 487: Reward: 217.00
# Episode 488: Reward: 97.00
# Episode 489: Reward: 83.00
# Episode 490: Reward: 150.00
# Episode 491: Reward: 79.00
# Episode 492: Reward: 120.00
# Episode 493: Reward: 106.00
# Episode 494: Reward: 132.00
# Episode 495: Reward: 129.00
# Episode 496: Reward: 62.00
# Episode 497: Reward: 199.00
# Episode 498: Reward: 93.00
# Episode 499: Reward: 150.00
# Episode 500: Reward: 135.00
# Episode 501: Reward: 218.00
# Episode 502: Reward: 168.00
# Episode 503: Reward: 156.00
# Episode 504: Reward: 128.00
# Episode 505: Reward: 109.00
# Episode 506: Reward: 81.00
# Episode 507: Reward: 159.00
# Episode 508: Reward: 133.00
# Episode 509: Reward: 50.00
# Episode 510: Reward: 101.00
# Episode 511: Reward: 110.00
# Episode 512: Reward: 174.00
# Episode 513: Reward: 274.00
# Episode 514: Reward: 22.00
# Episode 515: Reward: 91.00
# Episode 516: Reward: 99.00
# Episode 517: Reward: 130.00
# Episode 518: Reward: 67.00
# Episode 519: Reward: 306.00
# Episode 520: Reward: 194.00
# Episode 521: Reward: 197.00
# Episode 522: Reward: 98.00
# Episode 523: Reward: 157.00
# Episode 524: Reward: 113.00
# Episode 525: Reward: 73.00
# Episode 526: Reward: 190.00
# Episode 527: Reward: 142.00
# Episode 528: Reward: 138.00
# Episode 529: Reward: 64.00
# Episode 530: Reward: 268.00
# Episode 531: Reward: 162.00
# Episode 532: Reward: 109.00
# Episode 533: Reward: 207.00
# Episode 534: Reward: 81.00
# Episode 535: Reward: 163.00
# Episode 536: Reward: 68.00
# Episode 537: Reward: 144.00
# Episode 538: Reward: 137.00
# Episode 539: Reward: 168.00
# Episode 540: Reward: 182.00
# Episode 541: Reward: 103.00
# Episode 542: Reward: 110.00
# Episode 543: Reward: 88.00
# Episode 544: Reward: 118.00
# Episode 545: Reward: 169.00
# Episode 546: Reward: 73.00
# Episode 547: Reward: 141.00
# Episode 548: Reward: 249.00
# Episode 549: Reward: 116.00
# Episode 550: Reward: 86.00
# Episode 551: Reward: 51.00
# Episode 552: Reward: 54.00
# Episode 553: Reward: 102.00
# Episode 554: Reward: 147.00
# Episode 555: Reward: 176.00
# Episode 556: Reward: 70.00
# Episode 557: Reward: 114.00
# Episode 558: Reward: 95.00
# Episode 559: Reward: 108.00
# Episode 560: Reward: 80.00
# Episode 561: Reward: 103.00
# Episode 562: Reward: 86.00
# Episode 563: Reward: 46.00
# Episode 564: Reward: 196.00
# Episode 565: Reward: 113.00
# Episode 566: Reward: 194.00
# Episode 567: Reward: 184.00
# Episode 568: Reward: 162.00
# Episode 569: Reward: 86.00
# Episode 570: Reward: 78.00
# Episode 571: Reward: 149.00
# Episode 572: Reward: 102.00
# Episode 573: Reward: 240.00
# Episode 574: Reward: 169.00
# Episode 575: Reward: 93.00
# Episode 576: Reward: 89.00
# Episode 577: Reward: 122.00
# Episode 578: Reward: 115.00
# Episode 579: Reward: 108.00
# Episode 580: Reward: 119.00
# Episode 581: Reward: 246.00
# Episode 582: Reward: 198.00
# Episode 583: Reward: 100.00
# Episode 584: Reward: 114.00
# Episode 585: Reward: 53.00
# Episode 586: Reward: 234.00
# Episode 587: Reward: 189.00
# Episode 588: Reward: 138.00
# Episode 589: Reward: 139.00
# Episode 590: Reward: 97.00
# Episode 591: Reward: 174.00
# Episode 592: Reward: 272.00
# Episode 593: Reward: 112.00
# Episode 594: Reward: 90.00
# Episode 595: Reward: 155.00
# Episode 596: Reward: 96.00
# Episode 597: Reward: 58.00
# Episode 598: Reward: 138.00
# Episode 599: Reward: 127.00
# Episode 600: Reward: 161.00
# Episode 601: Reward: 104.00
# Episode 602: Reward: 78.00
# Episode 603: Reward: 381.00
# Episode 604: Reward: 193.00
# Episode 605: Reward: 90.00
# Episode 606: Reward: 76.00
# Episode 607: Reward: 93.00
# Episode 608: Reward: 214.00
# Episode 609: Reward: 68.00
# Episode 610: Reward: 97.00
# Episode 611: Reward: 193.00
# Episode 612: Reward: 110.00
# Episode 613: Reward: 103.00
# Episode 614: Reward: 403.00
# Episode 615: Reward: 125.00
# Episode 616: Reward: 65.00
# Episode 617: Reward: 154.00
# Episode 618: Reward: 110.00
# Episode 619: Reward: 106.00
# Episode 620: Reward: 86.00
# Episode 621: Reward: 108.00
# Episode 622: Reward: 123.00
# Episode 623: Reward: 77.00
# Episode 624: Reward: 125.00
# Episode 625: Reward: 444.00
# Episode 626: Reward: 174.00
# Episode 627: Reward: 84.00
# Episode 628: Reward: 188.00
# Episode 629: Reward: 198.00
# Episode 630: Reward: 83.00
# Episode 631: Reward: 104.00
# Episode 632: Reward: 111.00
# Episode 633: Reward: 94.00
# Episode 634: Reward: 113.00
# Episode 635: Reward: 112.00
# Episode 636: Reward: 147.00
# Episode 637: Reward: 112.00
# Episode 638: Reward: 154.00
# Episode 639: Reward: 97.00
# Episode 640: Reward: 229.00
# Episode 641: Reward: 106.00
# Episode 642: Reward: 371.00
# Episode 643: Reward: 137.00
# Episode 644: Reward: 147.00
# Episode 645: Reward: 121.00
# Episode 646: Reward: 148.00
# Episode 647: Reward: 102.00
# Episode 648: Reward: 199.00
# Episode 649: Reward: 90.00
# Episode 650: Reward: 191.00
# Episode 651: Reward: 191.00
# Episode 652: Reward: 162.00
# Episode 653: Reward: 92.00
# Episode 654: Reward: 253.00
# Episode 655: Reward: 113.00
# Episode 656: Reward: 119.00
# Episode 657: Reward: 157.00
# Episode 658: Reward: 217.00
# Episode 659: Reward: 134.00
# Episode 660: Reward: 159.00
# Episode 661: Reward: 145.00
# Episode 662: Reward: 92.00
# Episode 663: Reward: 33.00
# Episode 664: Reward: 93.00
# Episode 665: Reward: 127.00
# Episode 666: Reward: 152.00
# Episode 667: Reward: 112.00
# Episode 668: Reward: 122.00
# Episode 669: Reward: 138.00
# Episode 670: Reward: 171.00
# Episode 671: Reward: 87.00
# Episode 672: Reward: 175.00
# Episode 673: Reward: 126.00
# Episode 674: Reward: 115.00
# Episode 675: Reward: 58.00
# Episode 676: Reward: 153.00
# Episode 677: Reward: 143.00
# Episode 678: Reward: 301.00
# Episode 679: Reward: 217.00
# Episode 680: Reward: 251.00
# Episode 681: Reward: 179.00
# Episode 682: Reward: 113.00
# Episode 683: Reward: 129.00
# Episode 684: Reward: 125.00
# Episode 685: Reward: 107.00
# Episode 686: Reward: 189.00
# Episode 687: Reward: 266.00
# Episode 688: Reward: 101.00
# Episode 689: Reward: 99.00
# Episode 690: Reward: 123.00
# Episode 691: Reward: 125.00
# Episode 692: Reward: 186.00
# Episode 693: Reward: 271.00
# Episode 694: Reward: 108.00
# Episode 695: Reward: 203.00
# Episode 696: Reward: 195.00
# Episode 697: Reward: 104.00
# Episode 698: Reward: 174.00
# Episode 699: Reward: 184.00
# Episode 700: Reward: 131.00
# Episode 701: Reward: 120.00
# Episode 702: Reward: 323.00
# Episode 703: Reward: 102.00
# Episode 704: Reward: 130.00
# Episode 705: Reward: 121.00
# Episode 706: Reward: 103.00
# Episode 707: Reward: 210.00
# Episode 708: Reward: 119.00
# Episode 709: Reward: 418.00
# Episode 710: Reward: 86.00
# Episode 711: Reward: 153.00
# Episode 712: Reward: 90.00
# Episode 713: Reward: 119.00
# Episode 714: Reward: 201.00
# Episode 715: Reward: 123.00
# Episode 716: Reward: 201.00
# Episode 717: Reward: 113.00
# Episode 718: Reward: 80.00
# Episode 719: Reward: 188.00
# Episode 720: Reward: 182.00
# Episode 721: Reward: 141.00
# Episode 722: Reward: 201.00
# Episode 723: Reward: 185.00
# Episode 724: Reward: 114.00
# Episode 725: Reward: 105.00
# Episode 726: Reward: 139.00
# Episode 727: Reward: 88.00
# Episode 728: Reward: 170.00
# Episode 729: Reward: 183.00
# Episode 730: Reward: 141.00
# Episode 731: Reward: 124.00
# Episode 732: Reward: 326.00
# Episode 733: Reward: 207.00
# Episode 734: Reward: 117.00
# Episode 735: Reward: 137.00
# Episode 736: Reward: 87.00
# Episode 737: Reward: 124.00
# Episode 738: Reward: 85.00
# Episode 739: Reward: 131.00
# Episode 740: Reward: 282.00
# Episode 741: Reward: 147.00
# Episode 742: Reward: 111.00
# Episode 743: Reward: 146.00
# Episode 744: Reward: 202.00
# Episode 745: Reward: 102.00
# Episode 746: Reward: 95.00
# Episode 747: Reward: 120.00
# Episode 748: Reward: 102.00
# Episode 749: Reward: 131.00
# Episode 750: Reward: 192.00
# Episode 751: Reward: 400.00
# Episode 752: Reward: 143.00
# Episode 753: Reward: 236.00
# Episode 754: Reward: 132.00
# Episode 755: Reward: 165.00
# Episode 756: Reward: 165.00
# Episode 757: Reward: 187.00
# Episode 758: Reward: 101.00
# Episode 759: Reward: 128.00
# Episode 760: Reward: 129.00
# Episode 761: Reward: 109.00
# Episode 762: Reward: 164.00
# Episode 763: Reward: 119.00
# Episode 764: Reward: 171.00
# Episode 765: Reward: 347.00
# Episode 766: Reward: 104.00
# Episode 767: Reward: 137.00
# Episode 768: Reward: 97.00
# Episode 769: Reward: 167.00
# Episode 770: Reward: 163.00
# Episode 771: Reward: 193.00
# Episode 772: Reward: 95.00
# Episode 773: Reward: 171.00
# Episode 774: Reward: 157.00
# Episode 775: Reward: 89.00
# Episode 776: Reward: 125.00
# Episode 777: Reward: 278.00
# Episode 778: Reward: 210.00
# Episode 779: Reward: 194.00
# Episode 780: Reward: 211.00
# Episode 781: Reward: 89.00
# Episode 782: Reward: 200.00
# Episode 783: Reward: 228.00
# Episode 784: Reward: 153.00
# Episode 785: Reward: 113.00
# Episode 786: Reward: 170.00
# Episode 787: Reward: 180.00
# Episode 788: Reward: 243.00
# Episode 789: Reward: 189.00
# Episode 790: Reward: 91.00
# Episode 791: Reward: 117.00
# Episode 792: Reward: 179.00
# Episode 793: Reward: 207.00
# Episode 794: Reward: 108.00
# Episode 795: Reward: 187.00
# Episode 796: Reward: 135.00
# Episode 797: Reward: 176.00
# Episode 798: Reward: 87.00
# Episode 799: Reward: 103.00
# Episode 800: Reward: 161.00
# Episode 801: Reward: 89.00
# Episode 802: Reward: 140.00
# Episode 803: Reward: 184.00
# Episode 804: Reward: 112.00
# Episode 805: Reward: 247.00
# Episode 806: Reward: 196.00
# Episode 807: Reward: 253.00
# Episode 808: Reward: 106.00
# Episode 809: Reward: 131.00
# Episode 810: Reward: 139.00
# Episode 811: Reward: 125.00
# Episode 812: Reward: 126.00
# Episode 813: Reward: 296.00
# Episode 814: Reward: 122.00
# Episode 815: Reward: 153.00
# Episode 816: Reward: 157.00
# Episode 817: Reward: 166.00
# Episode 818: Reward: 445.00
# Episode 819: Reward: 100.00
# Episode 820: Reward: 134.00
# Episode 821: Reward: 93.00
# Episode 822: Reward: 176.00
# Episode 823: Reward: 150.00
# Episode 824: Reward: 50.00
# Episode 825: Reward: 186.00
# Episode 826: Reward: 108.00
# Episode 827: Reward: 101.00
# Episode 828: Reward: 178.00
# Episode 829: Reward: 112.00
# Episode 830: Reward: 118.00
# Episode 831: Reward: 139.00
# Episode 832: Reward: 315.00
# Episode 833: Reward: 243.00
# Episode 834: Reward: 266.00
# Episode 835: Reward: 129.00
# Episode 836: Reward: 283.00
# Episode 837: Reward: 147.00
# Episode 838: Reward: 159.00
# Episode 839: Reward: 258.00
# Episode 840: Reward: 181.00
# Episode 841: Reward: 90.00
# Episode 842: Reward: 229.00
# Episode 843: Reward: 225.00
# Episode 844: Reward: 97.00
# Episode 845: Reward: 179.00
# Episode 846: Reward: 294.00
# Episode 847: Reward: 132.00
# Episode 848: Reward: 142.00
# Episode 849: Reward: 190.00
# Episode 850: Reward: 169.00
# Episode 851: Reward: 198.00
# Episode 852: Reward: 180.00
# Episode 853: Reward: 78.00
# Episode 854: Reward: 297.00
# Episode 855: Reward: 187.00
# Episode 856: Reward: 112.00
# Episode 857: Reward: 235.00
# Episode 858: Reward: 111.00
# Episode 859: Reward: 115.00
# Episode 860: Reward: 175.00
# Episode 861: Reward: 132.00
# Episode 862: Reward: 128.00
# Episode 863: Reward: 116.00
# Episode 864: Reward: 85.00
# Episode 865: Reward: 149.00
# Episode 866: Reward: 235.00
# Episode 867: Reward: 295.00
# Episode 868: Reward: 94.00
# Episode 869: Reward: 319.00
# Episode 870: Reward: 500.00
# Solved!
