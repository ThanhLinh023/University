# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
DG = nx.Graph()
DG.add_edges_from([(0,1),(0,2),(1,2),(1,5),(2,3),(2,4),(3,4),(3,5),(4,5),(4,6),(4,7),(5,6),(5,7),(6,7)])

# %%
plt.axis('off')
nx.draw_networkx(DG, pos=nx.spring_layout(DG, seed=0),node_size=600,cmap='coolwarm',font_size='14',font_color='white')
# Out:
# c:\Users\Hii\AppData\Local\Programs\Python\Python312\Lib\site-packages\networkx\drawing\nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %%
print(f'Edge betweenness: {nx.edge_betweenness_centrality(DG, None, False, None, False)}')
# Out:
# Edge betweenness: {(0, 1): 3.0, (0, 2): 4.0, (1, 2): 2.333333333333333, (1, 5): 6.333333333333333, (2, 3): 2.833333333333333, (2, 4): 5.833333333333334, (5, 3): 2.833333333333333, (5, 4): 1.8333333333333333, (5, 6): 3.0, (5, 7): 3.0, (3, 4): 2.0, (4, 6): 3.0, (4, 7): 3.0, (6, 7): 1.0}

# %% [markdown]
# Sau khi bỏ 2 cạnh (1, 5)

# %%
DG2 = nx.Graph()
DG2.add_edges_from([(0,1),(0,2),(1,2),(2,3), (2,4),(3,4),(3,5),(4,5),(4,6),(4,7),(5,6),(5,7),(6,7)])
plt.axis('off')
nx.draw_networkx(DG2, pos=nx.spring_layout(DG2, seed=0),node_size=600,cmap='coolwarm',font_size='14',font_color='white')

# %%
print(f'Edge betweenness: {nx.edge_betweenness_centrality(DG2, None, False, None, False)}')
# Out:
# Edge betweenness: {(0, 1): 1.0, (0, 2): 6.0, (1, 2): 6.0, (2, 3): 4.5, (2, 4): 10.5, (3, 4): 2.0, (3, 5): 3.5, (4, 5): 2.5, (4, 6): 4.5, (4, 7): 4.5, (5, 6): 1.5, (5, 7): 1.5, (6, 7): 1.0}

# %% [markdown]
# Sau khi loại bỏ cạnh (2, 4)

# %%
DG3 = nx.Graph()
DG3.add_edges_from([(0,1),(0,2),(1,2),(2,3),(3,4),(3,5),(4,5),(4,6),(4,7),(5,6),(5,7),(6,7)])
plt.axis('off')
nx.draw_networkx(DG3, pos=nx.spring_layout(DG3, seed=0),node_size=600,cmap='coolwarm',font_size='14',font_color='white')

# %%
print(f'Edge betweenness: {nx.edge_betweenness_centrality(DG3, None, False, None, False)}')
# Out:
# Edge betweenness: {(0, 1): 1.0, (0, 2): 6.0, (1, 2): 6.0, (2, 3): 15.0, (3, 4): 8.0, (3, 5): 8.0, (4, 5): 1.0, (4, 6): 3.0, (4, 7): 3.0, (5, 6): 3.0, (5, 7): 3.0, (6, 7): 1.0}

# %% [markdown]
# Sau khi loại bỏ cạnh (2, 3)

# %%
DG4 = nx.Graph()
DG4.add_edges_from([(0,1),(0,2),(1,2),(3,4),(3,5),(4,5),(4,6),(4,7),(5,6),(5,7),(6,7)])
plt.axis('off')
nx.draw_networkx(DG4, pos=nx.spring_layout(DG4, seed=0),node_size=600,cmap='coolwarm',font_size='14',font_color='white')

# %%
print(f'Edge betweenness: {nx.edge_betweenness_centrality(DG4, None, False, None, False)}')
# Out:
# Edge betweenness: {(0, 1): 1.0, (0, 2): 1.0, (1, 2): 1.0, (3, 4): 2.0, (3, 5): 2.0, (4, 5): 1.0, (4, 6): 1.5, (4, 7): 1.5, (5, 6): 1.5, (5, 7): 1.5, (6, 7): 1.0}

# %% [markdown]
# Sau khi loại bỏ cạnh (3, 4) và (3, 5)

# %%
DG5 = nx.Graph()
DG5.add_edges_from([(0,1),(0,2),(1,2),(4,5),(4,6),(4,7),(5,6),(5,7),(6,7)])
plt.axis('off')
nx.draw_networkx(DG5, pos=nx.spring_layout(DG5, seed=0),node_size=600,cmap='coolwarm',font_size='14',font_color='white')

# %%
print(f'Edge betweenness: {nx.edge_betweenness_centrality(DG5, None, False, None, False)}')
# Out:
# Edge betweenness: {(0, 1): 1.0, (0, 2): 1.0, (1, 2): 1.0, (4, 5): 1.0, (4, 6): 1.0, (4, 7): 1.0, (5, 6): 1.0, (5, 7): 1.0, (6, 7): 1.0}
